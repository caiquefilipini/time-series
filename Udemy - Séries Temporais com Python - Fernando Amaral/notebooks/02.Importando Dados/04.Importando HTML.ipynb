# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\programdata\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\programdata\anaconda3\lib\site-packages (from html5lib) (1.15.0)

# %%
import os
import numpy as np
import pandas as pd
import html5lib

# %%
br = pd.read_html('https://pt.wikipedia.org/wiki/Unidades_federativas_do_Brasil')

# %%
print(type(br))
# Out:
# <class 'list'>

# %%
u = br[1]

# %%
u.head()
# Out:
#    Bandeira Unidade federativa Abreviação Sede de governo   Área (km²)  \
# 0       NaN               Acre         AC      Rio Branco    164 122,2
# 1       NaN            Alagoas         AL          Maceió     27 767,7
# 2       NaN              Amapá         AP          Macapá    142 814,6
# 3       NaN           Amazonas         AM          Manaus  1 570 745,7
# 4       NaN              Bahia         BA        Salvador    564 692,7
#
#   População (2014)  Densidade (2005)   PIB (2015)  (% total) (2015)  \
# 0          795 145               430   13 622 000                 2
# 1        3 327 551             10861   46 364 000                 8
# 2          756 500               416   13 861 000                 2
# 3        3 893 763               205   86 560 000                14
# 4       15 150 143              2446  245 025 000                41
#
#   PIB per capita (R$) (2015)  IDH (2010) Alfabetização (2016)  \
# 0                  16 953,46         663                86,9%
# 1                  13 877,53         631                80,6%
# 2                  18 079,54         708                  95%
# 3                  21 978,95         674                93,1%
# 4                  16 115,89         660                  87%
#
#   Mortalidade infantil (2016) Expectativa de vida (2016)
# 0                       17,0‰                  73,9 anos
# 1                       19,5‰                  71,6 anos
# 2                       23,2‰                  73,9 anos
# 3                       18,2‰                  71,9 anos
# 4                       17,3‰                  73,5 anos

# %%
bcs = pd.read_html('https://pt.wikipedia.org/wiki/Lista_dos_maiores_bancos_do_Brasil')

# %%
b = bcs[2]

# %%
b
# Out:
#     Posição            Nome do banco   Cidade sede  \
# 0         1      Banco Itaú Unibanco     São Paulo
# 1         2           Banco Bradesco        Osasco
# 2         3          Banco do Brasil     São Paulo
# 3         4  Caixa Econômica Federal      Brasília
# 4         5   Banco Santander Brasil     São Paulo
# 5         6                   Sicoob      Brasília
# 6         7        Banco BTG Pactual     São Paulo
# 7         8              Banco Safra     São Paulo
# 8         9         Banco Votorantim     São Paulo
# 9        10                 Banrisul  Porto Alegre
# 10       11          Citibank Brasil     São Paulo
# 11       12        Banco do Nordeste     Fortaleza
#
#     Patrimônio líquido em R$ milhões    Data dos dados  País de origem
# 0                           144.3290  Dezembro de 2019          Brasil
# 1                           138.9834  Dezembro de 2019          Brasil
# 2                           100.6455  Dezembro de 2019          Brasil
# 3                            80.7000  Dezembro de 2019          Brasil
# 4                            71.0191  Dezembro de 2019         Espanha
# 5                            23.4000  Dezembro de 2019          Brasil
# 6                            21.9837  Dezembro de 2019          Brasil
# 7                            12.1761  Dezembro de 2019          Brasil
# 8                            10.0271  Dezembro de 2019          Brasil
# 9                             7.9096  Dezembro de 2019          Brasil
# 10                            5.9030  Dezembro de 2019  Estados Unidos
# 11                            5.4378  Dezembro de 2019          Brasil
